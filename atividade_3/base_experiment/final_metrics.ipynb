# %% [markdown]
# ## Final metrics
#
# Here we have the best configurations for the three selected models, let's see how the behave of the test data.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %% [markdown]
# ## Data

# %%
data = pd.read_csv("text_databases/Dmoz-Sports.csv")
data.fillna('', inplace=True)
data
# Out:
#          file_name                                               text  \
# 0      3191005.txt  Bryant Bulldogs Official site with news, sched...
# 1      3193010.txt  Hirschbeck v. Alomar Covers a legal case betwe...
# 2      3190744.txt  Mountaineers Baseball Official site. Includes ...
# 3      3193695.txt  M.S.H. Little League Contains news items, a li...
# 4      3193486.txt  Quotations: Bob Uecker Baseball Almanac collec...
# ...            ...                                                ...
# 13495  3274147.txt  IMDb.com - Dwayne Johnson Filmography, awards,...
# 13496  3273536.txt  Suwannee Wrestling Includes pictures, and stat...
# 13497  3274032.txt   Jeff's Swanton Biography, facts and wallpapers.
# 13498  3274152.txt  Roddy Piper Tribute Includes background inform...
# 13499  3273727.txt  The Wrestler Revue Online magazine featuring i...
#
#            class
# 0       Baseball
# 1       Baseball
# 2       Baseball
# 3       Baseball
# 4       Baseball
# ...          ...
# 13495  Wrestling
# 13496  Wrestling
# 13497  Wrestling
# 13498  Wrestling
# 13499  Wrestling
#
# [13500 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# Same split used on hyperparameters search
X_train, X_test, y_train, y_test = train_test_split(data['text'], data['class'],
                                                    test_size=0.2, random_state=14,
                                                    stratify=data['class'])

split_data = [X_train, X_test, y_train, y_test]

# %% [markdown]
# ## MultinomialNB

# %%
df = pd.read_csv("/home/user/unb/unb_mestrado/2_semestre/topicos_nlp/nlp/outputs/MultinomialNB_grid_results.csv")
df.sort_values(by="rank_test_score")
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 1       0.897068      0.157417         0.114638        0.015831         0.20
# 2       0.962818      0.107601         0.144813        0.037077         0.50
# 0       0.697592      0.120070         0.106411        0.014254         0.10
# 3       0.980150      0.161476         0.138497        0.036620         0.75
# 4       1.024190      0.212656         0.152066        0.060670         1.00
# 5       1.087031      0.238688         0.137359        0.047433         1.50
# 6       1.115224      0.280644         0.140028        0.039944         2.00
# 7       0.847224      0.125853         0.055421        0.020471         5.00
#
#             params  split0_test_score  split1_test_score  split2_test_score  \
# 1   {'alpha': 0.2}           0.809722           0.822222           0.829167
# 2   {'alpha': 0.5}           0.806944           0.824537           0.829630
# 0   {'alpha': 0.1}           0.811574           0.819907           0.825926
# 3  {'alpha': 0.75}           0.805093           0.820833           0.823611
# 4     {'alpha': 1}           0.803704           0.815278           0.820370
# 5   {'alpha': 1.5}           0.805556           0.810185           0.814352
# 6     {'alpha': 2}           0.802315           0.806944           0.813426
# 7     {'alpha': 5}           0.786111           0.787037           0.806944
#
#    split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 1           0.822685           0.801389         0.817037        0.010043
# 2           0.818056           0.804167         0.816667        0.009825
# 0           0.820370           0.803704         0.816296        0.007788
# 3           0.815278           0.805093         0.813981        0.007738
# 4           0.810185           0.801852         0.810278        0.006944
# 5           0.806481           0.800463         0.807407        0.004657
# 6           0.801389           0.798148         0.804444        0.005300
# 7           0.786111           0.792130         0.791667        0.007960
#
#    rank_test_score
# 1                1
# 2                2
# 0                3
# 3                4
# 4                5
# 5                6
# 6                7
# 7                8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   mean_fit_time      8 non-null      float64
#  1   std_fit_time       8 non-null      float64
#  2   mean_score_time    8 non-null      float64
#  3   std_score_time     8 non-null      float64
#  4   param_alpha        8 non-null      float64
#  5   params             8 non-null      object
#  6   split0_test_score  8 non-null      float64
#  7   split1_test_score  8 non-null      float64
#  8   split2_test_score  8 non-null      float64
#  9   split3_test_score  8 non-null      float64
#  10  split4_test_score  8 non-null      float64
#  11  mean_test_score    8 non-null      float64
#  12  std_test_score     8 non-null      float64
#  13  rank_test_score    8 non-null      int64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 1.0+ KB

# %%
from ast import literal_eval

# best params
best_params = literal_eval(df.sort_values(by="rank_test_score").iloc[1]["params"])
best_params
# Out:
# {'alpha': 0.5}

# %%
from sklearn.naive_bayes import MultinomialNB

best_nb = MultinomialNB(**best_params)
best_nb.get_params()
# Out:
# {'alpha': 0.5, 'class_prior': None, 'fit_prior': True, 'force_alpha': True}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, ConfusionMatrixDisplay

import matplotlib.pyplot as plt

tfidf = TfidfVectorizer(ngram_range=(1,3))

# fit only on train
X_train_csr = tfidf.fit_transform(X_train)
X_test_csr = tfidf.transform(X_test)

best_nb.fit(X_train_csr, y_train)
preds = best_nb.predict(X_test_csr)

print(classification_report(y_test, preds))

ConfusionMatrixDisplay.from_predictions(
    y_true=y_test,
    y_pred=preds,
    xticks_rotation=90
)

plt.show()
# Out:
#               precision    recall  f1-score   support
#
#     Baseball       0.74      0.71      0.72       100
#   Basketball       0.83      0.74      0.78       100
#      Bowling       0.90      0.87      0.88       100
#      Cricket       0.67      0.91      0.77       100
#      Cycling       0.82      0.89      0.86       100
#   Equestrian       0.92      0.83      0.87       100
#      Fencing       0.82      0.89      0.85       100
#       Flying       0.70      0.86      0.77       100
#     Football       0.73      0.53      0.61       100
#         Golf       0.84      0.81      0.83       100
#   Gymnastics       0.84      0.86      0.85       100
#       Hockey       0.78      0.53      0.63       100
#     Lacrosse       0.67      0.84      0.75       100
#      Martial       0.95      0.97      0.96       100
#  Motorsports       0.86      0.70      0.77       100
#    Paintball       0.90      0.94      0.92       100
#      Running       0.86      0.83      0.85       100
#      Skating       0.87      0.90      0.88       100
#       Soccer       0.89      0.72      0.80       100
#     Softball       0.71      0.87      0.78       100
#     Strength       0.82      0.84      0.83       100
#       Tennis       0.85      0.89      0.87       100
#        Track       0.75      0.96      0.84       100
#   Volleyball       0.72      0.73      0.73       100
#        Water       0.97      0.63      0.76       100
#       Winter       0.90      0.83      0.86       100
#    Wrestling       0.78      0.83      0.81       100
#
#     accuracy                           0.81      2700
#    macro avg       0.82      0.81      0.81      2700
# weighted avg       0.82      0.81      0.81      2700

# %% [markdown]
# ## LogisticRegression

# %%
df = pd.read_csv("/home/user/unb/unb_mestrado/2_semestre/topicos_nlp/nlp/outputs/LogisticRegression_grid_results.csv")
df.sort_values(by="rank_test_score")
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 12      11.503161      1.056282         0.129310        0.031925   1.0000
# 14     130.186906      6.469831         0.058212        0.026933   1.0000
# 8       92.078277      4.465383         0.146872        0.074486   1.0000
# 13       1.291288      0.100626         0.133860        0.018223   1.0000
# 6        6.408795      0.664438         0.165440        0.035683   0.0001
# 9        2.101646      0.185860         0.125810        0.034897   1.0000
# 4      139.646434     11.344553         0.108898        0.009745   0.0001
# 0        1.302530      0.238343         0.114376        0.025054   0.0001
# 1        1.380401      0.243529         0.150989        0.052190   0.0001
# 15       2.068122      0.148113         0.112661        0.020890   1.0000
# 7        2.284982      0.168448         0.129944        0.023266   0.0001
# 5        9.338959      1.111112         0.182013        0.061808   0.0001
# 2        0.017146      0.004975         0.000000        0.000000   0.0001
# 3        0.013418      0.005085         0.000000        0.000000   0.0001
# 11       0.014260      0.002345         0.000000        0.000000   1.0000
# 10       0.013026      0.001163         0.000000        0.000000   1.0000
#
#    param_penalty param_solver  param_tol  \
# 12            l2         saga     0.0001
# 14            l2        lbfgs     0.0001
# 8             l1         saga     0.0001
# 13            l2         saga     1.0000
# 6             l2        lbfgs     0.0001
# 9             l1         saga     1.0000
# 4             l2         saga     0.0001
# 0             l1         saga     0.0001
# 1             l1         saga     1.0000
# 15            l2        lbfgs     1.0000
# 7             l2        lbfgs     1.0000
# 5             l2         saga     1.0000
# 2             l1        lbfgs     0.0001
# 3             l1        lbfgs     1.0000
# 11            l1        lbfgs     1.0000
# 10            l1        lbfgs     0.0001
#
#                                                params  split0_test_score  \
# 12  {'C': 1, 'penalty': 'l2', 'solver': 'saga', 't...           0.868056
# 14  {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs', '...           0.866667
# 8   {'C': 1, 'penalty': 'l1', 'solver': 'saga', 't...           0.831481
# 13  {'C': 1, 'penalty': 'l2', 'solver': 'saga', 't...           0.756944
# 6   {'C': 0.0001, 'penalty': 'l2', 'solver': 'lbfg...           0.769907
# 9   {'C': 1, 'penalty': 'l1', 'solver': 'saga', 't...           0.798611
# 4   {'C': 0.0001, 'penalty': 'l2', 'solver': 'saga...           0.612500
# 0   {'C': 0.0001, 'penalty': 'l1', 'solver': 'saga...           0.037037
# 1   {'C': 0.0001, 'penalty': 'l1', 'solver': 'saga...           0.037037
# 15  {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs', '...           0.037037
# 7   {'C': 0.0001, 'penalty': 'l2', 'solver': 'lbfg...           0.037037
# 5   {'C': 0.0001, 'penalty': 'l2', 'solver': 'saga...           0.037037
# 2   {'C': 0.0001, 'penalty': 'l1', 'solver': 'lbfg...                NaN
# 3   {'C': 0.0001, 'penalty': 'l1', 'solver': 'lbfg...                NaN
# 11  {'C': 1, 'penalty': 'l1', 'solver': 'lbfgs', '...                NaN
# 10  {'C': 1, 'penalty': 'l1', 'solver': 'lbfgs', '...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 12           0.858796           0.867130           0.862963
# 14           0.858333           0.866667           0.862963
# 8            0.819907           0.816204           0.828241
# 13           0.750000           0.771296           0.808796
# 6            0.769444           0.776852           0.755556
# 9            0.717593           0.742593           0.689815
# 4            0.572685           0.606944           0.593981
# 0            0.037037           0.037037           0.037037
# 1            0.037037           0.037037           0.037037
# 15           0.037037           0.037037           0.037037
# 7            0.037037           0.037037           0.037037
# 5            0.037037           0.037037           0.037037
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 10                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 12           0.857407         0.862870        0.004277                1
# 14           0.857407         0.862407        0.003954                2
# 8            0.833333         0.825833        0.006660                3
# 13           0.805093         0.778426        0.024306                4
# 6            0.769907         0.768333        0.006957                5
# 9            0.782407         0.746204        0.040171                6
# 4            0.586574         0.594537        0.014268                7
# 0            0.037037         0.037037        0.000000                8
# 1            0.037037         0.037037        0.000000                8
# 15           0.037037         0.037037        0.000000                8
# 7            0.037037         0.037037        0.000000                8
# 5            0.037037         0.037037        0.000000                8
# 2                 NaN              NaN             NaN               13
# 3                 NaN              NaN             NaN               13
# 11                NaN              NaN             NaN               13
# 10                NaN              NaN             NaN               13

# %%
from ast import literal_eval

# best params
best_params = literal_eval(df.sort_values(by="rank_test_score").iloc[1]["params"])
best_params
# Out:
# {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs', 'tol': 0.0001}

# %%
from sklearn.linear_model import LogisticRegression

best_logreg = LogisticRegression(**best_params)
best_logreg.get_params()
# Out:
# {'C': 1,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'deprecated',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
tfidf = TfidfVectorizer(ngram_range=(1,3))

# fit only on train
X_train_csr = tfidf.fit_transform(X_train)
X_test_csr = tfidf.transform(X_test)

best_logreg.fit(X_train_csr, y_train)
preds = best_logreg.predict(X_test_csr)

print(classification_report(y_test, preds))

ConfusionMatrixDisplay.from_predictions(
    y_true=y_test,
    y_pred=preds,
    xticks_rotation=90
)

plt.show()
# Out:
#               precision    recall  f1-score   support
#
#     Baseball       0.83      0.79      0.81       100
#   Basketball       0.89      0.80      0.84       100
#      Bowling       0.95      0.93      0.94       100
#      Cricket       0.97      0.84      0.90       100
#      Cycling       0.79      0.88      0.83       100
#   Equestrian       0.94      0.83      0.88       100
#      Fencing       0.94      0.89      0.91       100
#       Flying       0.76      0.91      0.83       100
#     Football       0.64      0.76      0.69       100
#         Golf       0.93      0.90      0.91       100
#   Gymnastics       0.99      0.87      0.93       100
#       Hockey       0.82      0.75      0.78       100
#     Lacrosse       0.99      0.97      0.98       100
#      Martial       0.93      0.98      0.96       100
#  Motorsports       0.77      0.77      0.77       100
#    Paintball       0.86      0.95      0.90       100
#      Running       0.93      0.91      0.92       100
#      Skating       0.96      0.89      0.92       100
#       Soccer       0.92      0.76      0.83       100
#     Softball       0.96      0.92      0.94       100
#     Strength       0.69      0.92      0.79       100
#       Tennis       0.95      0.89      0.92       100
#        Track       0.96      0.94      0.95       100
#   Volleyball       0.81      0.97      0.88       100
#        Water       0.92      0.82      0.87       100
#       Winter       0.94      0.85      0.89       100
#    Wrestling       0.81      0.91      0.86       100
#
#     accuracy                           0.87      2700
#    macro avg       0.88      0.87      0.88      2700
# weighted avg       0.88      0.87      0.88      2700

# %% [markdown]
# ## The mysterious competitor
